# %%
import numpy as np
import pandas as pd

# %%
# Define the KNN class
class KNN:
    def __init__(self, k=3, distance_metric='euclidean'):
        self.k = k
        self.distance_metric = distance_metric

    def fit(self, X, y):
        # TODO: Implement the fit method
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        # TODO: Implement the predict method
        predictions = []
        for x in X.values:
            distances = self.compute_distance(x, self.X_train.values)
            k_indices = np.argsort(distances)[:self.k]
            k_nearest_labels = [self.y_train.iloc[i] for i in k_indices]
            predictions.append(pd.Series(k_nearest_labels).mode()[0])  # majority class
        return np.array(predictions)
    
    def predict_proba(self, X_test):
        probabilities = []
        for x in X_test.itertuples(index=False):
            distances = np.linalg.norm(self.X_train.values - np.array(x), axis=1)
            nearest_neighbors_idx = np.argsort(distances)[:self.k]
            nearest_neighbors_labels = self.y_train.iloc[nearest_neighbors_idx]
            
            # Calculate the probability of the positive class (1)
            prob = np.mean(nearest_neighbors_labels == 1)
            probabilities.append(prob)
            
        return np.array(probabilities)


    def compute_distance(self, X1, X2):
        # TODO: Implement distance computation based on self.distance_metric
        # Hint: Use numpy operations for efficient computation
        if self.distance_metric == 'euclidean':
            return np.sqrt(np.sum((X2 - X1) ** 2, axis=1))
        elif self.distance_metric == 'manhattan':
            return np.sum(np.abs(X2 - X1), axis=1)
        else:
            raise ValueError("Unsupported distance metric")

# %%
# Define data preprocessing function
class CustomLabelEncoder:
    def __init__(self):
        self.mapping = {}
        self.inverse_mapping = {}
        
    def fit(self, y):
        unique_values = np.unique(y)
        self.mapping = {value: idx for idx, value in enumerate(unique_values)}
        self.inverse_mapping = {idx: value for value, idx in self.mapping.items()}


    def transform(self, y):
        return np.array([self.mapping.get(value, -1) for value in y])  # Assign -1 for unseen categories
    
    def fit_transform(self, y):
        self.fit(y)
        return self.transform(y)

class CustomStandardScaler:
    def fit(self, X):
        self.mean = np.mean(X, axis=0)
        self.std = np.std(X, axis=0)
        
    def transform(self, X):
        return (X - self.mean) / self.std
    
    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

def preprocess_data(train_path, test_path, target_column):
    train_data = pd.read_csv(train_path)
    test_data = pd.read_csv(test_path)

    # df_majority = train_data[train_data[target_column] == 0]
    # df_minority = train_data[train_data[target_column] == 1]

    # df_minority_oversampled = df_minority.sample(n=len(df_majority), 
    #                                               replace=True, 
    #                                               random_state=123)

    # train_data = pd.concat([df_majority, df_minority_oversampled])
    # print("\nNew class distribution after oversampling:")
    # print(train_data[target_column].value_counts())

    unique_values_train = train_data[target_column].unique()

    
    train_data = train_data.drop(columns=['Surname', 'CustomerId', 'id'])
    test_data = test_data.drop(columns=['Surname', 'CustomerId', 'id'])


    # TODO: Implement data preprocessing
    # Handle categorical variables, scale features, etc.
    categorical_cols = train_data.select_dtypes(include=['object']).columns.tolist()
    numerical_cols = train_data.select_dtypes(exclude=['object']).columns.tolist()

    label_encoders = {}
    for col in categorical_cols:
        le = CustomLabelEncoder()
        train_data[col] = le.fit_transform(train_data[col])
        test_data[col] = le.transform(test_data[col])  
        label_encoders[col] = le

    # Scale numerical features
    exclude_numerical_col = ['HasCrCard', 'IsActiveMember', 'Exited']
    scaler = CustomStandardScaler()
    numerical_cols = [col for col in numerical_cols if col not in exclude_numerical_col]

    train_data[numerical_cols] = scaler.fit_transform(train_data[numerical_cols])
    # test_data[numerical_cols] = scaler.transform(test_data[numerical_cols])

    if all(col in test_data.columns for col in numerical_cols):
        test_data[numerical_cols] = scaler.transform(test_data[numerical_cols])
    else:
        print(f"Warning: Some numerical columns are missing in test data: {set(numerical_cols) - set(test_data.columns)}")

    # Separate features and target variable
    if target_column in train_data.columns:
        y_train = train_data[target_column]  
        X_train = train_data.drop(target_column, axis=1)  
    
    else:
        raise KeyError(f"Target column '{target_column}' not found in training data")

    # If the test data has a target column, separate it; otherwise, just return X_test
    if target_column in test_data.columns:
        X_test = test_data.drop(target_column, axis=1)
        y_test = test_data[target_column]
    else:
        X_test = test_data  # Only features available for prediction
        y_test = None

    return X_train, y_train, X_test, y_test

# %%
# Define cross-validation function
def compute_roc_auc(y_true, y_scores):
    # Ensure y_true is a NumPy array
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)

    # Sort the scores and corresponding true labels
    sorted_indices = np.argsort(y_scores)[::-1]
    y_true_sorted = y_true[sorted_indices]
    y_scores_sorted = y_scores[sorted_indices]

    # Calculate true positive and false positive rates
    tp = np.cumsum(y_true_sorted) 
    fp = np.cumsum(1 - y_true_sorted)  
    tpr = tp / np.sum(y_true)  
    fpr = fp / np.sum(1 - y_true)  

    # Ensure TPR and FPR are clipped between 0 and 1
    tpr = np.clip(tpr, 0, 1)
    fpr = np.clip(fpr, 0, 1)

    # Compute AUC using the trapezoidal rule
    auc = np.trapz(tpr, fpr)
    
    print("y_true_sorted:", y_true_sorted)
    print("y_scores_sorted:", y_scores_sorted)
    print("TPR:", tpr)
    print("FPR:", fpr)
    print("AUC:", auc)

    return auc

def cross_validate(X, y, knn, n_splits=5):
    # TODO: Implement cross-validation
    # Compute ROC AUC scores
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    fold_sizes = np.full(n_splits, X.shape[0] // n_splits, dtype=int)
    fold_sizes[:X.shape[0] % n_splits] += 1
    current = 0
    folds = []
    for fold_size in fold_sizes:
        folds.append(indices[current:current + fold_size])
        current += fold_size

    auc_scores = []

    for fold in range(n_splits):
        val_indices = folds[fold]
        train_indices = np.concatenate(folds[:fold] + folds[fold + 1:])
        
        X_train, y_train = X.iloc[train_indices], y.iloc[train_indices]
        X_val, y_val = X.iloc[val_indices], y.iloc[val_indices]
        
        # Fit KNN on training data
        knn.fit(X_train, y_train)
        
        y_val_pred_proba = knn.predict_proba(X_val)         

        # Compute ROC AUC score
        auc = compute_roc_auc(y_val, y_val_pred_proba)
        print(f"AUC for fold {fold}: {auc}")

        auc_scores.append(auc)

    return np.mean(auc_scores), auc_scores

# %%
def encode_labels(y):
    return (y > 0).astype(int)

# Load and preprocess data
print("Loading and preprocessing data...")

X_train, y_train, X_test, y_test = preprocess_data('cs-506-predicting-customer-churn-using-knn/train.csv', 'cs-506-predicting-customer-churn-using-knn/test.csv', target_column='Exited')


y_train_encoded  = encode_labels(y_train)

threshold = 0  # Adjust based on your data distribution
y_train_binary = (y_train > 0).astype(int)

print("Data loading and preprocessing complete.")

# Create and evaluate model
print("Creating KNN model...")
knn = KNN(k=5, distance_metric='euclidean')
print("KNN model created.")


# Perform cross-validation
print("Starting cross-validation...")

cv_scores = cross_validate(X_train, y_train, knn)

print("Cross-validation complete. Scores:", cv_scores)


# TODO: hyperparamters tuning
print("Beginning hyperparameter tuning...")
best_k = None
best_metric = None
best_score = float('-inf') 

for k in range(5, 25):  
    for metric in ['euclidean', 'manhattan']:
        print(f"Testing with k={k} and metric={metric}")
        knn = KNN(k=k, distance_metric=metric)
        
        knn.fit(X_train, y_train)

        mean_cv_score, cv_scores = cross_validate(X_train, y_train, knn)


        print(f"Cross-validation scores: {cv_scores}")

        print(f"k: {k}, metric: {metric}, mean cross-validation score: {mean_cv_score}")
        
        # Update best parameters if this score is better
        if mean_cv_score > best_score:
            best_k = k
            best_metric = metric
            best_score = mean_cv_score

print(f"Best k: {best_k}, Best Metric: {best_metric}, Best CV Score: {best_score}")


# TODO: Train on full dataset with optimal hyperparameters and make predictions on test set
knn = KNN(k=best_k, distance_metric=best_metric)  # Use tuned parameters

knn.fit(X_train, y_train)

print("Model training complete.")

print("Making predictions on the test set...")

test_probabilities = knn.predict_proba(X_test)

predictions = knn.predict(X_test)

print("Predictions complete.")


# Save test predictions
print("Saving test predictions to 'submissions.csv'...")
pd.DataFrame({'id': pd.read_csv('cs-506-predicting-customer-churn-using-knn/test.csv')['id'], 'Exited': test_probabilities}).to_csv('submissions2.csv', index=False)

print("Predictions saved successfully.")
# Out:
# Loading and preprocessing data...
# Data loading and preprocessing complete.
# Creating KNN model...
# KNN model created.
# Starting cross-validation...
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169779 0.00339559 0.00509338 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917047 0.99958523 1.        ]
# AUC: 0.8604894516431831
# AUC for fold 0: 0.8604894516431831
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169492 0.00338983 0.00508475 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917012 0.99958506 1.        ]
# AUC: 0.8855327378859273
# AUC for fold 1: 0.8855327378859273
# y_true_sorted: [1. 1. 1. ... 1. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165289 0.00330579 0.00495868 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916493 0.99958246 1.        ]
# AUC: 0.8889256198347107
# AUC for fold 2: 0.8889256198347107
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165017 0.00330033 0.0049505  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916458 0.99958229 1.        ]
# AUC: 0.8928943646244324
# AUC for fold 3: 0.8928943646244324
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00155521 0.00311042 0.00466563 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915146 0.99957573 1.        ]
# AUC: 0.8741922904606971
# AUC for fold 4: 0.8741922904606971
# Cross-validation complete. Scores: (0.8804068928897901, [0.8604894516431831, 0.8855327378859273, 0.8889256198347107, 0.8928943646244324, 0.8741922904606971])
# Beginning hyperparameter tuning...
# Testing with k=5 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167504 0.00335008 0.00502513 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916771 0.99958385 1.        ]
# AUC: 0.8813452754129923
# AUC for fold 0: 0.8813452754129923
# y_true_sorted: [1. 1. 0. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159744 0.00319489 0.00319489 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 0.00000000e+00 4.21229992e-04 ... 9.99157540e-01
#  9.99578770e-01 1.00000000e+00]
# AUC: 0.8898073108300519
# AUC for fold 1: 0.8898073108300519
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00161551 0.00323102 0.00484653 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916002 0.99958001 1.        ]
# AUC: 0.8900096957673125
# AUC for fold 2: 0.8900096957673125
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166113 0.00332226 0.00498339 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916597 0.99958299 1.        ]
# AUC: 0.8750349820864007
# AUC for fold 3: 0.8750349820864007
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169779 0.00339559 0.00509338 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917047 0.99958523 1.        ]
# AUC: 0.8759484507552044
# AUC for fold 4: 0.8759484507552044
# Cross-validation scores: [0.8813452754129923, 0.8898073108300519, 0.8900096957673125, 0.8750349820864007, 0.8759484507552044]
# k: 5, metric: euclidean, mean cross-validation score: 0.8824291429703923
# Testing with k=5 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159236 0.00318471 0.00477707 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915683 0.99957841 1.        ]
# AUC: 0.8891580111921461
# AUC for fold 0: 0.8891580111921461
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.8833448436225109
# AUC for fold 1: 0.8833448436225109
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00161812 0.00323625 0.00485437 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916037 0.99958018 1.        ]
# AUC: 0.8965318366714762
# AUC for fold 2: 0.8965318366714762
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00178571 0.00357143 0.00535714 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99918033 0.99959016 1.        ]
# AUC: 0.8796296838407494
# AUC for fold 3: 0.8796296838407494
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158983 0.00317965 0.00476948 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915647 0.99957824 1.        ]
# AUC: 0.8623973168097017
# AUC for fold 4: 0.8623973168097017
# Cross-validation scores: [0.8891580111921461, 0.8833448436225109, 0.8965318366714762, 0.8796296838407494, 0.8623973168097017]
# k: 5, metric: manhattan, mean cross-validation score: 0.8822123384273169
# Testing with k=6 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158983 0.00317965 0.00476948 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915647 0.99957824 1.        ]
# AUC: 0.8904797570538012
# AUC for fold 0: 0.8904797570538012
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00177305 0.0035461  0.00531915 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917898 0.99958949 1.        ]
# AUC: 0.8821227684030325
# AUC for fold 1: 0.8821227684030325
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0016129  0.00322581 0.00483871 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915966 0.99957983 1.        ]
# AUC: 0.8858701545134182
# AUC for fold 2: 0.8858701545134182
# y_true_sorted: [1. 1. 1. ... 1. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170648 0.00341297 0.00511945 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991715  0.99958575 1.        ]
# AUC: 0.8780662291355037
# AUC for fold 3: 0.8780662291355037
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00157729 0.00315457 0.00473186 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915469 0.99957735 1.        ]
# AUC: 0.893503790555477
# AUC for fold 4: 0.893503790555477
# Cross-validation scores: [0.8904797570538012, 0.8821227684030325, 0.8858701545134182, 0.8780662291355037, 0.893503790555477]
# k: 6, metric: euclidean, mean cross-validation score: 0.8860085399322465
# Testing with k=6 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164204 0.00328407 0.00492611 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916353 0.99958176 1.        ]
# AUC: 0.8885661130718026
# AUC for fold 0: 0.8885661130718026
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165017 0.00330033 0.0049505  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916458 0.99958229 1.        ]
# AUC: 0.8744978507875849
# AUC for fold 1: 0.8744978507875849
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169492 0.00338983 0.00508475 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917012 0.99958506 1.        ]
# AUC: 0.8814058653913777
# AUC for fold 2: 0.8814058653913777
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0015873 0.0031746 0.0047619 ... 1.        1.        1.       ]
# FPR: [0.         0.         0.         ... 0.99915612 0.99957806 1.        ]
# AUC: 0.9119958475654679
# AUC for fold 3: 0.9119958475654679
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.8892338881478368
# AUC for fold 4: 0.8892338881478368
# Cross-validation scores: [0.8885661130718026, 0.8744978507875849, 0.8814058653913777, 0.9119958475654679, 0.8892338881478368]
# k: 6, metric: manhattan, mean cross-validation score: 0.8891399129928139
# Testing with k=7 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170358 0.00340716 0.00511073 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917116 0.99958558 1.        ]
# AUC: 0.8898011975168575
# AUC for fold 0: 0.8898011975168575
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00157233 0.00314465 0.00471698 ... 0.99842767 0.99842767 1.        ]
# FPR: [0.         0.         0.         ... 0.99957699 1.         1.        ]
# AUC: 0.8920694590769296
# AUC for fold 1: 0.8920694590769296
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00175439 0.00350877 0.00526316 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917695 0.99958848 1.        ]
# AUC: 0.9016894087069527
# AUC for fold 2: 0.9016894087069527
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158479 0.00316957 0.00475436 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915576 0.99957788 1.        ]
# AUC: 0.8876006044798136
# AUC for fold 3: 0.8876006044798136
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164204 0.00328407 0.00492611 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916353 0.99958176 1.        ]
# AUC: 0.8891292538590596
# AUC for fold 4: 0.8891292538590596
# Cross-validation scores: [0.8898011975168575, 0.8920694590769296, 0.9016894087069527, 0.8876006044798136, 0.8891292538590596]
# k: 7, metric: euclidean, mean cross-validation score: 0.8920579847279226
# Testing with k=7 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0016835  0.003367   0.00505051 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916874 0.99958437 1.        ]
# AUC: 0.9075627429742142
# AUC for fold 0: 0.9075627429742142
# y_true_sorted: [1. 1. 0. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00176367 0.00352734 0.00352734 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 0.00000000e+00 4.11015208e-04 ... 9.99177970e-01
#  9.99588985e-01 1.00000000e+00]
# AUC: 0.8871107225676345
# AUC for fold 1: 0.8871107225676345
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00156495 0.00312989 0.00469484 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991529  0.99957645 1.        ]
# AUC: 0.8957922792058483
# AUC for fold 2: 0.8957922792058483
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160772 0.00321543 0.00482315 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915896 0.99957948 1.        ]
# AUC: 0.8824345081792098
# AUC for fold 3: 0.8824345081792098
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163666 0.00327332 0.00490998 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916283 0.99958141 1.        ]
# AUC: 0.8987510267668439
# AUC for fold 4: 0.8987510267668439
# Cross-validation scores: [0.9075627429742142, 0.8871107225676345, 0.8957922792058483, 0.8824345081792098, 0.8987510267668439]
# k: 7, metric: manhattan, mean cross-validation score: 0.89433025593875
# Testing with k=8 and metric=euclidean
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00160256 0.00320513 ... 1.         1.         1.        ]
# FPR: [4.20875421e-04 4.20875421e-04 4.20875421e-04 ... 9.99158249e-01
#  9.99579125e-01 1.00000000e+00]
# AUC: 0.877328978891479
# AUC for fold 0: 0.877328978891479
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.9037705613686362
# AUC for fold 1: 0.9037705613686362
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166113 0.00332226 0.00498339 ... 0.99833887 0.99833887 1.        ]
# FPR: [0.         0.         0.         ... 0.99958299 1.         1.        ]
# AUC: 0.9037556213788345
# AUC for fold 2: 0.9037556213788345
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.8969995124146987
# AUC for fold 3: 0.8969995124146987
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163934 0.00327869 0.00491803 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916318 0.99958159 1.        ]
# AUC: 0.8982221002812264
# AUC for fold 4: 0.8982221002812264
# Cross-validation scores: [0.877328978891479, 0.9037705613686362, 0.9037556213788345, 0.8969995124146987, 0.8982221002812264]
# k: 8, metric: euclidean, mean cross-validation score: 0.8960153548669749
# Testing with k=8 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165017 0.00330033 0.0049505  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916458 0.99958229 1.        ]
# AUC: 0.8983997397233457
# AUC for fold 0: 0.8983997397233457
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159744 0.00319489 0.00479233 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915754 0.99957877 1.        ]
# AUC: 0.8954831494545543
# AUC for fold 1: 0.8954831494545543
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162602 0.00325203 0.00487805 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916143 0.99958071 1.        ]
# AUC: 0.8946089209319765
# AUC for fold 2: 0.8946089209319765
# y_true_sorted: [0. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00163934 0.00327869 ... 0.99836066 0.99836066 1.        ]
# FPR: [4.18410042e-04 4.18410042e-04 4.18410042e-04 ... 9.99581590e-01
#  1.00000000e+00 1.00000000e+00]
# AUC: 0.8976068317442898
# AUC for fold 3: 0.8976068317442898
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00173611 0.00347222 0.00520833 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917492 0.99958746 1.        ]
# AUC: 0.8973588765126512
# AUC for fold 4: 0.8973588765126512
# Cross-validation scores: [0.8983997397233457, 0.8954831494545543, 0.8946089209319765, 0.8976068317442898, 0.8973588765126512]
# k: 8, metric: manhattan, mean cross-validation score: 0.8966915036733637
# Testing with k=9 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.8858320584261131
# AUC for fold 0: 0.8858320584261131
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00155763 0.00311526 0.0046729  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915182 0.99957591 1.        ]
# AUC: 0.9064693929857661
# AUC for fold 1: 0.9064693929857661
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00162075 0.00324149 ... 1.         1.         1.        ]
# FPR: [4.19639110e-04 4.19639110e-04 4.19639110e-04 ... 9.99160722e-01
#  9.99580361e-01 1.00000000e+00]
# AUC: 0.9099591855056516
# AUC for fold 2: 0.9099591855056516
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00175747 0.00351494 ... 1.         1.         1.        ]
# FPR: [4.11353353e-04 4.11353353e-04 4.11353353e-04 ... 9.99177293e-01
#  9.99588647e-01 1.00000000e+00]
# AUC: 0.9055889835379136
# AUC for fold 3: 0.9055889835379136
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164204 0.00328407 0.00492611 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916353 0.99958176 1.        ]
# AUC: 0.899641444140211
# AUC for fold 4: 0.899641444140211
# Cross-validation scores: [0.8858320584261131, 0.9064693929857661, 0.9099591855056516, 0.9055889835379136, 0.899641444140211]
# k: 9, metric: euclidean, mean cross-validation score: 0.901498212919131
# Testing with k=9 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00173611 0.00347222 0.00520833 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917492 0.99958746 1.        ]
# AUC: 0.9027097371195453
# AUC for fold 0: 0.9027097371195453
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0016129  0.00322581 0.00483871 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915966 0.99957983 1.        ]
# AUC: 0.89444361615614
# AUC for fold 1: 0.89444361615614
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.901144903907358
# AUC for fold 2: 0.901144903907358
# y_true_sorted: [1. 1. 1. ... 0. 1. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0015674  0.0031348  0.00470219 ... 0.9984326  1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99957663 0.99957663 1.        ]
# AUC: 0.8955410775098941
# AUC for fold 3: 0.8955410775098941
# y_true_sorted: [1. 0. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00165837 0.00331675 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 4.17188152e-04 4.17188152e-04 ... 9.99165624e-01
#  9.99582812e-01 1.00000000e+00]
# AUC: 0.8923626894037668
# AUC for fold 4: 0.8923626894037668
# Cross-validation scores: [0.9027097371195453, 0.89444361615614, 0.901144903907358, 0.8955410775098941, 0.8923626894037668]
# k: 9, metric: manhattan, mean cross-validation score: 0.8972404048193408
# Testing with k=10 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00331675 0.00497512 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916562 0.99958281 1.        ]
# AUC: 0.9097828891974559
# AUC for fold 0: 0.9097828891974559
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00161551 0.00323102 0.00484653 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916002 0.99958001 1.        ]
# AUC: 0.9096760229577316
# AUC for fold 1: 0.9096760229577316
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00168634 0.00337268 0.00505902 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916909 0.99958455 1.        ]
# AUC: 0.9039325295600031
# AUC for fold 2: 0.9039325295600031
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165017 0.00330033 0.0049505  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916458 0.99958229 1.        ]
# AUC: 0.8906948338944171
# AUC for fold 3: 0.8906948338944171
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163399 0.00326797 0.00490196 ... 0.99836601 0.99836601 1.        ]
# FPR: [0.         0.         0.         ... 0.99958124 1.         1.        ]
# AUC: 0.8895231878345978
# AUC for fold 4: 0.8895231878345978
# Cross-validation scores: [0.9097828891974559, 0.9096760229577316, 0.9039325295600031, 0.8906948338944171, 0.8895231878345978]
# k: 10, metric: euclidean, mean cross-validation score: 0.9007218926888412
# Testing with k=10 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 1. 1. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162866 0.00325733 0.00488599 ... 0.99837134 1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99958089 0.99958089 1.        ]
# AUC: 0.8886883585300791
# AUC for fold 0: 0.8886883585300791
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164474 0.00328947 0.00493421 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916388 0.99958194 1.        ]
# AUC: 0.9017922955905651
# AUC for fold 1: 0.9017922955905651
# y_true_sorted: [1. 0. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159236 0.00159236 0.00318471 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 4.21585160e-04 4.21585160e-04 ... 9.99156830e-01
#  9.99578415e-01 1.00000000e+00]
# AUC: 0.9094759991836823
# AUC for fold 2: 0.9094759991836823
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00172712 0.00345423 0.00518135 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991739  0.99958695 1.        ]
# AUC: 0.8984518736815673
# AUC for fold 3: 0.8984518736815673
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165563 0.00331126 0.00496689 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916528 0.99958264 1.        ]
# AUC: 0.9188555152627448
# AUC for fold 4: 0.9188555152627448
# Cross-validation scores: [0.8886883585300791, 0.9017922955905651, 0.9094759991836823, 0.8984518736815673, 0.9188555152627448]
# k: 10, metric: manhattan, mean cross-validation score: 0.9034528084497276
# Testing with k=11 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159744 0.00319489 0.00479233 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915754 0.99957877 1.        ]
# AUC: 0.8948916779488119
# AUC for fold 0: 0.8948916779488119
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163399 0.00326797 0.00490196 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916248 0.99958124 1.        ]
# AUC: 0.9097249592187516
# AUC for fold 1: 0.9097249592187516
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00156986 0.00313972 0.00470958 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915362 0.99957681 1.        ]
# AUC: 0.9111485213897403
# AUC for fold 2: 0.9111485213897403
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0017301  0.00346021 0.00519031 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917424 0.99958712 1.        ]
# AUC: 0.8993232451089922
# AUC for fold 3: 0.8993232451089922
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00172414 0.00344828 0.00517241 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917355 0.99958678 1.        ]
# AUC: 0.9066051581647193
# AUC for fold 4: 0.9066051581647193
# Cross-validation scores: [0.8948916779488119, 0.9097249592187516, 0.9111485213897403, 0.8993232451089922, 0.9066051581647193]
# k: 11, metric: euclidean, mean cross-validation score: 0.9043387123662029
# Testing with k=11 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.8950260471920402
# AUC for fold 0: 0.8950260471920402
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164474 0.00328947 0.00493421 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916388 0.99958194 1.        ]
# AUC: 0.9039891744411195
# AUC for fold 1: 0.9039891744411195
# y_true_sorted: [1. 1. 1. ... 0. 1. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00173611 0.00347222 0.00520833 ... 0.99826389 1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99958746 0.99958746 1.        ]
# AUC: 0.8936195051796847
# AUC for fold 2: 0.8936195051796847
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158228 0.00316456 0.00474684 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915541 0.9995777  1.        ]
# AUC: 0.9107095129148136
# AUC for fold 3: 0.9107095129148136
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00161031 0.00322061 ... 1.         1.         1.        ]
# FPR: [4.20344683e-04 4.20344683e-04 4.20344683e-04 ... 9.99159311e-01
#  9.99579655e-01 1.00000000e+00]
# AUC: 0.8982826787530993
# AUC for fold 4: 0.8982826787530993
# Cross-validation scores: [0.8950260471920402, 0.9039891744411195, 0.8936195051796847, 0.9107095129148136, 0.8982826787530993]
# k: 11, metric: manhattan, mean cross-validation score: 0.9003253836961514
# Testing with k=12 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.9033013617015964
# AUC for fold 0: 0.9033013617015964
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00154799 0.00309598 0.00464396 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915038 0.99957519 1.        ]
# AUC: 0.9002067490681824
# AUC for fold 1: 0.9002067490681824
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164474 0.00328947 0.00493421 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916388 0.99958194 1.        ]
# AUC: 0.9088539374669953
# AUC for fold 2: 0.9088539374669953
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170358 0.00340716 0.00511073 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917116 0.99958558 1.        ]
# AUC: 0.9096673258351448
# AUC for fold 3: 0.9096673258351448
# y_true_sorted: [1. 1. 1. ... 1. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169205 0.00338409 0.00507614 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916978 0.99958489 1.        ]
# AUC: 0.9081686765436157
# AUC for fold 4: 0.9081686765436157
# Cross-validation scores: [0.9033013617015964, 0.9002067490681824, 0.9088539374669953, 0.9096673258351448, 0.9081686765436157]
# k: 12, metric: euclidean, mean cross-validation score: 0.9060396101231071
# Testing with k=12 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158228 0.00316456 0.00474684 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915541 0.9995777  1.        ]
# AUC: 0.905978714078002
# AUC for fold 0: 0.905978714078002
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00168634 0.00337268 0.00505902 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916909 0.99958455 1.        ]
# AUC: 0.9043122539585569
# AUC for fold 1: 0.9043122539585569
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00155521 0.00311042 0.00466563 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915146 0.99957573 1.        ]
# AUC: 0.8995197126325672
# AUC for fold 2: 0.8995197126325672
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163934 0.00327869 0.00491803 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916318 0.99958159 1.        ]
# AUC: 0.9014088757802318
# AUC for fold 3: 0.9014088757802318
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0018018  0.0036036  0.00540541 ... 0.9981982  0.9981982  1.        ]
# FPR: [0.       0.       0.       ... 0.999591 1.       1.      ]
# AUC: 0.9033556255642146
# AUC for fold 4: 0.9033556255642146
# Cross-validation scores: [0.905978714078002, 0.9043122539585569, 0.8995197126325672, 0.9014088757802318, 0.9033556255642146]
# k: 12, metric: manhattan, mean cross-validation score: 0.9029150364027145
# Testing with k=13 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00331675 0.00497512 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916562 0.99958281 1.        ]
# AUC: 0.8974305222600667
# AUC for fold 0: 0.8974305222600667
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.9096704529948566
# AUC for fold 1: 0.9096704529948566
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158983 0.00317965 0.00476948 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915647 0.99957824 1.        ]
# AUC: 0.9024775389426691
# AUC for fold 2: 0.9024775389426691
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.9120411729890898
# AUC for fold 3: 0.9120411729890898
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164745 0.00329489 0.00494234 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916423 0.99958211 1.        ]
# AUC: 0.9058126014164046
# AUC for fold 4: 0.9058126014164046
# Cross-validation scores: [0.8974305222600667, 0.9096704529948566, 0.9024775389426691, 0.9120411729890898, 0.9058126014164046]
# k: 13, metric: euclidean, mean cross-validation score: 0.9054864577206174
# Testing with k=13 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160256 0.00320513 0.00480769 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915825 0.99957912 1.        ]
# AUC: 0.8985616042907709
# AUC for fold 0: 0.8985616042907709
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163132 0.00326264 0.00489396 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916213 0.99958106 1.        ]
# AUC: 0.9148999713647401
# AUC for fold 1: 0.9148999713647401
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163666 0.00327332 0.00490998 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916283 0.99958141 1.        ]
# AUC: 0.9105858205811004
# AUC for fold 2: 0.9105858205811004
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163934 0.00327869 0.00491803 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916318 0.99958159 1.        ]
# AUC: 0.9026400987722066
# AUC for fold 3: 0.9026400987722066
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00173913 0.00347826 0.00521739 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917526 0.99958763 1.        ]
# AUC: 0.9109185118780815
# AUC for fold 4: 0.9109185118780815
# Cross-validation scores: [0.8985616042907709, 0.9148999713647401, 0.9105858205811004, 0.9026400987722066, 0.9109185118780815]
# k: 13, metric: manhattan, mean cross-validation score: 0.9075212013773799
# Testing with k=14 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166113 0.00332226 0.00498339 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916597 0.99958299 1.        ]
# AUC: 0.9036932770664369
# AUC for fold 0: 0.9036932770664369
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.9077250018899999
# AUC for fold 1: 0.9077250018899999
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00153846 0.00307692 0.00461538 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99914894 0.99957447 1.        ]
# AUC: 0.9184909983633388
# AUC for fold 2: 0.9184909983633388
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167504 0.00335008 0.00502513 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916771 0.99958385 1.        ]
# AUC: 0.903914774315467
# AUC for fold 3: 0.903914774315467
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00171527 0.00343053 0.0051458  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917253 0.99958626 1.        ]
# AUC: 0.9072670641276663
# AUC for fold 4: 0.9072670641276663
# Cross-validation scores: [0.9036932770664369, 0.9077250018899999, 0.9184909983633388, 0.903914774315467, 0.9072670641276663]
# k: 14, metric: euclidean, mean cross-validation score: 0.9082182231525817
# Testing with k=14 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166667 0.00333333 0.005      ... 0.99833333 0.99833333 1.        ]
# FPR: [0.         0.         0.         ... 0.99958333 1.         1.        ]
# AUC: 0.9008777777777779
# AUC for fold 0: 0.9008777777777779
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162075 0.00324149 0.00486224 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916072 0.99958036 1.        ]
# AUC: 0.9023573924156181
# AUC for fold 1: 0.9023573924156181
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162075 0.00324149 0.00486224 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916072 0.99958036 1.        ]
# AUC: 0.9052030488787746
# AUC for fold 2: 0.9052030488787746
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0017452 0.0034904 0.0052356 ... 1.        1.        1.       ]
# FPR: [0.         0.         0.         ... 0.99917594 0.99958797 1.        ]
# AUC: 0.9208993356444479
# AUC for fold 3: 0.9208993356444479
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159744 0.00319489 0.00479233 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915754 0.99957877 1.        ]
# AUC: 0.9092666560798426
# AUC for fold 4: 0.9092666560798426
# Cross-validation scores: [0.9008777777777779, 0.9023573924156181, 0.9052030488787746, 0.9208993356444479, 0.9092666560798426]
# k: 14, metric: manhattan, mean cross-validation score: 0.9077208421592922
# Testing with k=15 and metric=euclidean
# y_true_sorted: [0. 0. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.         0.00156006 ... 1.         1.         1.        ]
# FPR: [4.23908436e-04 8.47816872e-04 8.47816872e-04 ... 9.99152183e-01
#  9.99576092e-01 1.00000000e+00]
# AUC: 0.9035922437321402
# AUC for fold 0: 0.9035922437321402
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165563 0.00331126 0.00496689 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916528 0.99958264 1.        ]
# AUC: 0.9166450154230561
# AUC for fold 1: 0.9166450154230561
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170358 0.00340716 0.00511073 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917116 0.99958558 1.        ]
# AUC: 0.9091081739950623
# AUC for fold 2: 0.9091081739950623
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00331675 0.00497512 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916562 0.99958281 1.        ]
# AUC: 0.9068826359095912
# AUC for fold 3: 0.9068826359095912
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.9022699868281449
# AUC for fold 4: 0.9022699868281449
# Cross-validation scores: [0.9035922437321402, 0.9166450154230561, 0.9091081739950623, 0.9068826359095912, 0.9022699868281449]
# k: 15, metric: euclidean, mean cross-validation score: 0.9076996111775989
# Testing with k=15 and metric=manhattan
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00157233 0.00314465 ... 1.         1.         1.        ]
# FPR: [4.23011844e-04 4.23011844e-04 4.23011844e-04 ... 9.99153976e-01
#  9.99576988e-01 1.00000000e+00]
# AUC: 0.9081126488522812
# AUC for fold 0: 0.9081126488522812
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164745 0.00329489 0.00494234 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916423 0.99958211 1.        ]
# AUC: 0.9090648108052659
# AUC for fold 1: 0.9090648108052659
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00163666 0.00327332 ... 1.         1.         1.        ]
# FPR: [4.18585182e-04 4.18585182e-04 4.18585182e-04 ... 9.99162830e-01
#  9.99581415e-01 1.00000000e+00]
# AUC: 0.9103090474001475
# AUC for fold 2: 0.9103090474001475
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00172117 0.00344234 0.00516351 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917321 0.99958661 1.        ]
# AUC: 0.9062051074432971
# AUC for fold 3: 0.9062051074432971
# y_true_sorted: [1. 1. 1. ... 0. 0. 1.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 0.99832776 0.99832776 1.        ]
# FPR: [0.         0.         0.         ... 0.99958368 1.         1.        ]
# AUC: 0.9162932784552449
# AUC for fold 4: 0.9162932784552449
# Cross-validation scores: [0.9081126488522812, 0.9090648108052659, 0.9103090474001475, 0.9062051074432971, 0.9162932784552449]
# k: 15, metric: manhattan, mean cross-validation score: 0.9099969785912474
# Testing with k=16 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0017301  0.00346021 0.00519031 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917424 0.99958712 1.        ]
# AUC: 0.9041342480548833
# AUC for fold 0: 0.9041342480548833
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00161031 0.00322061 0.00483092 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915931 0.99957966 1.        ]
# AUC: 0.9048843239862485
# AUC for fold 1: 0.9048843239862485
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158983 0.00317965 0.00476948 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915647 0.99957824 1.        ]
# AUC: 0.9196759465695383
# AUC for fold 2: 0.9196759465695383
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165017 0.00330033 0.0049505  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916458 0.99958229 1.        ]
# AUC: 0.9080201879837106
# AUC for fold 3: 0.9080201879837106
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166945 0.0033389  0.00500835 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916701 0.99958351 1.        ]
# AUC: 0.9096884367184235
# AUC for fold 4: 0.9096884367184235
# Cross-validation scores: [0.9041342480548833, 0.9048843239862485, 0.9196759465695383, 0.9080201879837106, 0.9096884367184235]
# k: 16, metric: euclidean, mean cross-validation score: 0.9092806286625608
# Testing with k=16 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.9155748528738455
# AUC for fold 0: 0.9155748528738455
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169492 0.00338983 0.00508475 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917012 0.99958506 1.        ]
# AUC: 0.9171313031858781
# AUC for fold 1: 0.9171313031858781
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00156495 0.00312989 0.00469484 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991529  0.99957645 1.        ]
# AUC: 0.9158933079866558
# AUC for fold 2: 0.9158933079866558
# y_true_sorted: [1. 1. 0. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00176367 0.00352734 0.00352734 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 0.00000000e+00 4.11015208e-04 ... 9.99177970e-01
#  9.99588985e-01 1.00000000e+00]
# AUC: 0.8951171828278282
# AUC for fold 3: 0.8951171828278282
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00156006 0.00312012 0.00468019 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915218 0.99957609 1.        ]
# AUC: 0.9062699430401973
# AUC for fold 4: 0.9062699430401973
# Cross-validation scores: [0.9155748528738455, 0.9171313031858781, 0.9158933079866558, 0.8951171828278282, 0.9062699430401973]
# k: 16, metric: manhattan, mean cross-validation score: 0.909997317982881
# Testing with k=17 and metric=euclidean
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.        0.0017452 0.0034904 ... 1.        1.        1.       ]
# FPR: [4.12031314e-04 4.12031314e-04 4.12031314e-04 ... 9.99175937e-01
#  9.99587969e-01 1.00000000e+00]
# AUC: 0.912605497633876
# AUC for fold 0: 0.912605497633876
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162338 0.00324675 0.00487013 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916107 0.99958054 1.        ]
# AUC: 0.9026430260176065
# AUC for fold 1: 0.9026430260176065
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.91244410628666
# AUC for fold 2: 0.91244410628666
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163132 0.00326264 0.00489396 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916213 0.99958106 1.        ]
# AUC: 0.9124779341060981
# AUC for fold 3: 0.9124779341060981
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0015873 0.0031746 0.0047619 ... 1.        1.        1.       ]
# FPR: [0.         0.         0.         ... 0.99915612 0.99957806 1.        ]
# AUC: 0.9081843145134285
# AUC for fold 4: 0.9081843145134285
# Cross-validation scores: [0.912605497633876, 0.9026430260176065, 0.91244410628666, 0.9124779341060981, 0.9081843145134285]
# k: 17, metric: euclidean, mean cross-validation score: 0.9096709757115338
# Testing with k=17 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00158479 0.00316957 0.00475436 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915576 0.99957788 1.        ]
# AUC: 0.9181303136993348
# AUC for fold 0: 0.9181303136993348
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00169492 0.00338983 0.00508475 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917012 0.99958506 1.        ]
# AUC: 0.9232984035445532
# AUC for fold 1: 0.9232984035445532
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167504 0.00335008 0.00502513 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916771 0.99958385 1.        ]
# AUC: 0.8959480437281427
# AUC for fold 2: 0.8959480437281427
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00161551 0.00323102 0.00484653 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916002 0.99958001 1.        ]
# AUC: 0.9125399721407834
# AUC for fold 3: 0.9125399721407834
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.901006711409396
# AUC for fold 4: 0.901006711409396
# Cross-validation scores: [0.9181303136993348, 0.9232984035445532, 0.8959480437281427, 0.9125399721407834, 0.901006711409396]
# k: 17, metric: manhattan, mean cross-validation score: 0.910184688904442
# Testing with k=18 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00331675 0.00497512 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916562 0.99958281 1.        ]
# AUC: 0.906101532388122
# AUC for fold 0: 0.906101532388122
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.9022769486965989
# AUC for fold 1: 0.9022769486965989
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00154799 0.00309598 0.00464396 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915038 0.99957519 1.        ]
# AUC: 0.9183768619910513
# AUC for fold 2: 0.9183768619910513
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162866 0.00325733 0.00488599 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916178 0.99958089 1.        ]
# AUC: 0.9223578911729934
# AUC for fold 3: 0.9223578911729934
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00174825 0.0034965  0.00524476 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917628 0.99958814 1.        ]
# AUC: 0.9077754000529947
# AUC for fold 4: 0.9077754000529947
# Cross-validation scores: [0.906101532388122, 0.9022769486965989, 0.9183768619910513, 0.9223578911729934, 0.9077754000529947]
# ...
# FPR: [0.         0.         0.         ... 0.99917831 0.99958915 1.        ]
# AUC: 0.9195198469270727
# AUC for fold 4: 0.9195198469270727
# Cross-validation scores: [0.9136948532583379, 0.920627694069705, 0.9018877861715959, 0.9078694176257801, 0.9195198469270727]
# k: 20, metric: euclidean, mean cross-validation score: 0.9127199196104983
# Testing with k=20 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00148588 0.00297177 0.00445765 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99914052 0.99957026 1.        ]
# AUC: 0.9088802487243555
# AUC for fold 0: 0.9088802487243555
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00176991 0.00353982 0.00530973 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917864 0.99958932 1.        ]
# AUC: 0.919201904381167
# AUC for fold 1: 0.919201904381167
# y_true_sorted: [1. 0. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165837 0.00165837 0.00331675 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 4.17188152e-04 4.17188152e-04 ... 9.99165624e-01
#  9.99582812e-01 1.00000000e+00]
# AUC: 0.9052699235016685
# AUC for fold 2: 0.9052699235016685
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00171821 0.00343643 0.00515464 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917287 0.99958644 1.        ]
# AUC: 0.9069066764444217
# AUC for fold 3: 0.9069066764444217
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163934 0.00327869 0.00491803 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916318 0.99958159 1.        ]
# AUC: 0.9159688593181974
# AUC for fold 4: 0.9159688593181974
# Cross-validation scores: [0.9088802487243555, 0.919201904381167, 0.9052699235016685, 0.9069066764444217, 0.9159688593181974]
# k: 20, metric: manhattan, mean cross-validation score: 0.911245522473962
# Testing with k=21 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160514 0.00321027 0.00481541 ... 1.         1.         1.        ]
# FPR: [0.        0.        0.        ... 0.9991586 0.9995793 1.       ]
# AUC: 0.9190624976787309
# AUC for fold 0: 0.9190624976787309
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170648 0.00341297 0.00511945 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991715  0.99958575 1.        ]
# AUC: 0.9051162021314799
# AUC for fold 1: 0.9051162021314799
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00157729 0.00315457 0.00473186 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915469 0.99957735 1.        ]
# AUC: 0.9132172122951061
# AUC for fold 2: 0.9132172122951061
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167224 0.00334448 0.00501672 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916736 0.99958368 1.        ]
# AUC: 0.9047630319215592
# AUC for fold 3: 0.9047630319215592
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00168919 0.00337838 0.00506757 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916944 0.99958472 1.        ]
# AUC: 0.9196028721828141
# AUC for fold 4: 0.9196028721828141
# Cross-validation scores: [0.9190624976787309, 0.9051162021314799, 0.9132172122951061, 0.9047630319215592, 0.9196028721828141]
# k: 21, metric: euclidean, mean cross-validation score: 0.9123523632419379
# Testing with k=21 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00171527 0.00343053 0.0051458  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917253 0.99958626 1.        ]
# AUC: 0.9150329534011161
# AUC for fold 0: 0.9150329534011161
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00159744 0.00319489 0.00479233 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915754 0.99957877 1.        ]
# AUC: 0.8939846203950679
# AUC for fold 1: 0.8939846203950679
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160514 0.00321027 0.00481541 ... 1.         1.         1.        ]
# FPR: [0.        0.        0.        ... 0.9991586 0.9995793 1.       ]
# AUC: 0.9119207547450114
# AUC for fold 2: 0.9119207547450114
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00172712 0.00345423 0.00518135 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991739  0.99958695 1.        ]
# AUC: 0.9200896873142959
# AUC for fold 3: 0.9200896873142959
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160772 0.00321543 0.00482315 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915896 0.99957948 1.        ]
# AUC: 0.9167286406204788
# AUC for fold 4: 0.9167286406204788
# Cross-validation scores: [0.9150329534011161, 0.8939846203950679, 0.9119207547450114, 0.9200896873142959, 0.9167286406204788]
# k: 21, metric: manhattan, mean cross-validation score: 0.911551331295194
# Testing with k=22 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170068 0.00340136 0.00510204 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917081 0.99958541 1.        ]
# AUC: 0.9103314211256642
# AUC for fold 0: 0.9103314211256642
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.9152149502115066
# AUC for fold 1: 0.9152149502115066
# y_true_sorted: [1. 1. 0. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160256 0.00320513 0.00320513 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 0.00000000e+00 4.20875421e-04 ... 9.99158249e-01
#  9.99579125e-01 1.00000000e+00]
# AUC: 0.9277551152551153
# AUC for fold 2: 0.9277551152551153
# y_true_sorted: [1. 1. 1. ... 1. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162602 0.00325203 0.00487805 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916143 0.99958071 1.        ]
# AUC: 0.8996921818274786
# AUC for fold 3: 0.8996921818274786
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165289 0.00330579 0.00495868 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916493 0.99958246 1.        ]
# AUC: 0.9086637105540123
# AUC for fold 4: 0.9086637105540123
# Cross-validation scores: [0.9103314211256642, 0.9152149502115066, 0.9277551152551153, 0.8996921818274786, 0.9086637105540123]
# k: 22, metric: euclidean, mean cross-validation score: 0.9123314757947554
# Testing with k=22 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0016835  0.003367   0.00505051 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916874 0.99958437 1.        ]
# AUC: 0.9156492886750576
# AUC for fold 0: 0.9156492886750576
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00171233 0.00342466 0.00513699 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917219 0.99958609 1.        ]
# AUC: 0.9166274494239318
# AUC for fold 1: 0.9166274494239318
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166667 0.00333333 0.005      ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916667 0.99958333 1.        ]
# AUC: 0.9142993055555556
# AUC for fold 2: 0.9142993055555556
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00157978 0.00315956 0.00473934 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915505 0.99957752 1.        ]
# AUC: 0.9194319470390325
# AUC for fold 3: 0.9194319470390325
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00160772 0.00321543 0.00482315 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915896 0.99957948 1.        ]
# AUC: 0.8996076034604452
# AUC for fold 4: 0.8996076034604452
# Cross-validation scores: [0.9156492886750576, 0.9166274494239318, 0.9142993055555556, 0.9194319470390325, 0.8996076034604452]
# k: 22, metric: manhattan, mean cross-validation score: 0.9131231188308047
# Testing with k=23 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162075 0.00324149 0.00486224 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916072 0.99958036 1.        ]
# AUC: 0.9004652757137777
# AUC for fold 0: 0.9004652757137777
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170068 0.00340136 0.00510204 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917081 0.99958541 1.        ]
# AUC: 0.9146508105729855
# AUC for fold 1: 0.9146508105729855
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00172117 0.00344234 0.00516351 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99917321 0.99958661 1.        ]
# AUC: 0.9176819484872698
# AUC for fold 2: 0.9176819484872698
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00165289 0.00330579 0.00495868 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916493 0.99958246 1.        ]
# AUC: 0.9176162459669768
# AUC for fold 3: 0.9176162459669768
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00155763 0.00311526 0.0046729  ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915182 0.99957591 1.        ]
# AUC: 0.9114091618907202
# AUC for fold 4: 0.9114091618907202
# Cross-validation scores: [0.9004652757137777, 0.9146508105729855, 0.9176819484872698, 0.9176162459669768, 0.9114091618907202]
# k: 23, metric: euclidean, mean cross-validation score: 0.912364688526346
# Testing with k=23 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166389 0.00332779 0.00499168 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916632 0.99958316 1.        ]
# AUC: 0.9232923590597579
# AUC for fold 0: 0.9232923590597579
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164204 0.00328407 0.00492611 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916353 0.99958176 1.        ]
# AUC: 0.9140914993898165
# AUC for fold 1: 0.9140914993898165
# y_true_sorted: [0. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.         0.00167504 0.00335008 ... 1.         1.         1.        ]
# FPR: [4.16146484e-04 4.16146484e-04 4.16146484e-04 ... 9.99167707e-01
#  9.99583854e-01 1.00000000e+00]
# AUC: 0.9109125876295057
# AUC for fold 2: 0.9109125876295057
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00167785 0.0033557  0.00503356 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916805 0.99958403 1.        ]
# AUC: 0.900148940803359
# AUC for fold 3: 0.900148940803359
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0015873 0.0031746 0.0047619 ... 1.        1.        1.       ]
# FPR: [0.         0.         0.         ... 0.99915612 0.99957806 1.        ]
# AUC: 0.9170356975420266
# AUC for fold 4: 0.9170356975420266
# Cross-validation scores: [0.9232923590597579, 0.9140914993898165, 0.9109125876295057, 0.900148940803359, 0.9170356975420266]
# k: 23, metric: manhattan, mean cross-validation score: 0.9130962168848932
# Testing with k=24 and metric=euclidean
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163399 0.00326797 0.00490196 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916248 0.99958124 1.        ]
# AUC: 0.908912755498626
# AUC for fold 0: 0.908912755498626
# y_true_sorted: [1. 0. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163666 0.00163666 0.00327332 ... 1.         1.         1.        ]
# FPR: [0.00000000e+00 4.18585182e-04 4.18585182e-04 ... 9.99162830e-01
#  9.99581415e-01 1.00000000e+00]
# AUC: 0.9054853841152748
# AUC for fold 1: 0.9054853841152748
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00168067 0.00336134 0.00504202 ... 1.         1.         1.        ]
# FPR: [0.        0.        0.        ... 0.9991684 0.9995842 1.       ]
# AUC: 0.9176952776952777
# AUC for fold 2: 0.9176952776952777
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00162602 0.00325203 0.00487805 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916143 0.99958071 1.        ]
# AUC: 0.9154362461863612
# AUC for fold 3: 0.9154362461863612
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00166667 0.00333333 0.005      ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916667 0.99958333 1.        ]
# AUC: 0.9177847222222222
# AUC for fold 4: 0.9177847222222222
# Cross-validation scores: [0.908912755498626, 0.9054853841152748, 0.9176952776952777, 0.9154362461863612, 0.9177847222222222]
# k: 24, metric: euclidean, mean cross-validation score: 0.9130628771435525
# Testing with k=24 and metric=manhattan
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164204 0.00328407 0.00492611 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916353 0.99958176 1.        ]
# AUC: 0.9136451073023566
# AUC for fold 0: 0.9136451073023566
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00164745 0.00329489 0.00494234 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916423 0.99958211 1.        ]
# AUC: 0.9211655907434575
# AUC for fold 1: 0.9211655907434575
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.0016129  0.00322581 0.00483871 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99915966 0.99957983 1.        ]
# AUC: 0.9091068040119273
# AUC for fold 2: 0.9091068040119273
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00170648 0.00341297 0.00511945 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.9991715  0.99958575 1.        ]
# AUC: 0.9116431170843572
# AUC for fold 3: 0.9116431170843572
# y_true_sorted: [1. 1. 1. ... 0. 0. 0.]
# y_scores_sorted: [1. 1. 1. ... 0. 0. 0.]
# TPR: [0.00163666 0.00327332 0.00490998 ... 1.         1.         1.        ]
# FPR: [0.         0.         0.         ... 0.99916283 0.99958141 1.        ]
# AUC: 0.9056265110342754
# AUC for fold 4: 0.9056265110342754
# Cross-validation scores: [0.9136451073023566, 0.9211655907434575, 0.9091068040119273, 0.9116431170843572, 0.9056265110342754]
# k: 24, metric: manhattan, mean cross-validation score: 0.9122374260352748
# Best k: 22, Best Metric: manhattan, Best CV Score: 0.9131231188308047
# Model training complete.
# Making predictions on the test set...
# Predictions complete.
# Saving test predictions to 'submissions.csv'...
# Predictions saved successfully.

# %%
print("Predictions complete.")


# Save test predictions
print("Saving test predictions to 'submissions.csv'...")
pd.DataFrame({'id': pd.read_csv('cs-506-predicting-customer-churn-using-knn/test.csv')['id'], 'Exited': test_probabilities}).to_csv('submissions3.csv', index=False)

print("Predictions saved successfully.")
# Out:
# Predictions complete.
# Saving test predictions to 'submissions1.csv'...
# Predictions saved successfully.
